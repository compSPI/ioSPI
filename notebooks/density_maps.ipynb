# %% [markdown]
# # Density Maps Basic Tour
# ## Requirements
#   - Installation of ioSPI and all including libraries
#   - Installation of `matplotlib` for visualization
#
# ## Getting Started
# In order to be able to import the ioSPI code we should change our path.

# %%
import os
import sys
import warnings

sys.path.append(os.path.dirname(os.getcwd()))
warnings.filterwarnings('ignore')

# %% [markdown]
# Now, run the following cells to import the required packages.

# %%
from ioSPI import density_maps

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading Density Maps
# We can use `density_maps.read_density_map_from_mrc` function to read a density map from a `.mrc` file.

# %%
data = density_maps.read_density_map_from_mrc('data/EMD-5592.map')
print(data.shape)
# Out:
# (261, 250, 274)

# %% [markdown]
# To get a cubic np array we can use `make_cubic` option.

# %%
data = density_maps.read_density_map_from_mrc('data/EMD-5592.map', make_cubic=True)
print(data.shape)
# Out:
# (274, 274, 274)

# %% [markdown]
# ## Visualization
# For visualization purposes, we illustrate three side views of the given map.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,15))
ax1.imshow(data.sum(0))
ax2.imshow(data.sum(1))
ax3.imshow(data.sum(2))
plt.show()
